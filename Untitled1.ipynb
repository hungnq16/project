# %%
import pandas as panda
#import data from file
df = panda.read_csv("Training Data.csv")

# %%
df
# Out:
#             Id   Income  Age  Experience Married/Single House_Ownership  \
# 0            1  1303834   23           3         single          rented
# 1            2  7574516   40          10         single          rented
# 2            3  3991815   66           4        married          rented
# 3            4  6256451   41           2         single          rented
# 4            5  5768871   47          11         single          rented
# ...        ...      ...  ...         ...            ...             ...
# 251995  251996  8154883   43          13         single          rented
# 251996  251997  2843572   26          10         single          rented
# 251997  251998  4522448   46           7         single          rented
# 251998  251999  6507128   45           0         single          rented
# 251999  252000  9070230   70          17         single          rented
#
#        Car_Ownership           Profession                 CITY  \
# ...

# %%
#check how many different answer in each group
df1 = panda.get_dummies(df["Car_Ownership"])
print(df1)
# Out:
#         no  yes
# 0        1    0
# 1        1    0
# 2        1    0
# 3        0    1
# 4        1    0
# ...     ..  ...
# 251995   1    0
# 251996   1    0
# 251997   1    0
# 251998   1    0
# 251999   1    0
#
# [252000 rows x 2 columns]

# %%
# Replace answer with dummy variable
df["Married/Single"].replace(["single", "married"], [0,1], inplace= True)

# %%
df
# Out:
#             Id   Income  Age  Experience  Married/Single House_Ownership  \
# 0            1  1303834   23           3               0          rented
# 1            2  7574516   40          10               0          rented
# 2            3  3991815   66           4               1          rented
# 3            4  6256451   41           2               0          rented
# 4            5  5768871   47          11               0          rented
# ...        ...      ...  ...         ...             ...             ...
# 251995  251996  8154883   43          13               0          rented
# 251996  251997  2843572   26          10               0          rented
# 251997  251998  4522448   46           7               0          rented
# 251998  251999  6507128   45           0               0          rented
# 251999  252000  9070230   70          17               0          rented
#
#        Car_Ownership           Profession                 CITY  \
# ...

# %%
df["House_Ownership"].replace(["norent_noown", "rented", "owned"], [0,1,2], inplace= True) 
df
# Out:
#             Id   Income  Age  Experience  Married/Single  House_Ownership  \
# 0            1  1303834   23           3               0                1
# 1            2  7574516   40          10               0                1
# 2            3  3991815   66           4               1                1
# 3            4  6256451   41           2               0                1
# 4            5  5768871   47          11               0                1
# ...        ...      ...  ...         ...             ...              ...
# 251995  251996  8154883   43          13               0                1
# 251996  251997  2843572   26          10               0                1
# 251997  251998  4522448   46           7               0                1
# 251998  251999  6507128   45           0               0                1
# 251999  252000  9070230   70          17               0                1
#
#        Car_Ownership           Profession                 CITY  \
# ...

# %%
df["Car_Ownership"].replace(["no", "yes"], [0,1,], inplace= True) 
df
# Out:
#             Id   Income  Age  Experience  Married/Single  House_Ownership  \
# 0            1  1303834   23           3               0                1
# 1            2  7574516   40          10               0                1
# 2            3  3991815   66           4               1                1
# 3            4  6256451   41           2               0                1
# 4            5  5768871   47          11               0                1
# ...        ...      ...  ...         ...             ...              ...
# 251995  251996  8154883   43          13               0                1
# 251996  251997  2843572   26          10               0                1
# 251997  251998  4522448   46           7               0                1
# 251998  251999  6507128   45           0               0                1
# 251999  252000  9070230   70          17               0                1
#
#         Car_Ownership           Profession                 CITY  \
# ...

# %%
#Remove unnecessary data (State, City, Profession)
del df[("STATE")]
df
# Out:
#             Id   Income  Age  Experience  Married/Single  House_Ownership  \
# 0            1  1303834   23           3               0                1
# 1            2  7574516   40          10               0                1
# 2            3  3991815   66           4               1                1
# 3            4  6256451   41           2               0                1
# 4            5  5768871   47          11               0                1
# ...        ...      ...  ...         ...             ...              ...
# 251995  251996  8154883   43          13               0                1
# 251996  251997  2843572   26          10               0                1
# 251997  251998  4522448   46           7               0                1
# 251998  251999  6507128   45           0               0                1
# 251999  252000  9070230   70          17               0                1
#
#         Car_Ownership  CURRENT_JOB_YRS  CURRENT_HOUSE_YRS  Risk_Flag
# ...

# %%
#Export cleaned data to csv.
df.to_csv("Training_data_cleaned.csv")

# %%
df2 = panda.read_csv("Test Data.csv")
df2
# Out:
#           ID   Income  Age  Experience Married/Single House_Ownership  \
# 0          1  7393090   59          19         single          rented
# 1          2  1215004   25           5         single          rented
# 2          3  8901342   50          12         single          rented
# 3          4  1944421   49           9        married          rented
# 4          5    13429   25          18         single          rented
# ...      ...      ...  ...         ...            ...             ...
# 27995  27996  9955481   57          13         single          rented
# 27996  27997  2917765   47           9         single          rented
# 27997  27998  8082415   24           5         single          rented
# 27998  27999  9474180   51          13         single          rented
# 27999  28000  9250350   42           9         single          rented
#
#       Car_Ownership            Profession            CITY           STATE  \
# ...

# %%
# Clean the test data file
df2["Married/Single"].replace(["single", "married"], [0,1], inplace= True) 
df2["House_Ownership"].replace(["norent_noown", "rented", "owned"], [0,1,2], inplace= True) 
df2["Car_Ownership"].replace(["no", "yes"], [0,1,], inplace= True)
del df2[("STATE")]
del df2[("Profession")]
del df2[("CITY")]
df2
# Out:
#           ID   Income  Age  Experience  Married/Single  House_Ownership  \
# 0          1  7393090   59          19               0                1
# 1          2  1215004   25           5               0                1
# 2          3  8901342   50          12               0                1
# 3          4  1944421   49           9               1                1
# 4          5    13429   25          18               0                1
# ...      ...      ...  ...         ...             ...              ...
# 27995  27996  9955481   57          13               0                1
# 27996  27997  2917765   47           9               0                1
# 27997  27998  8082415   24           5               0                1
# 27998  27999  9474180   51          13               0                1
# 27999  28000  9250350   42           9               0                1
#
#        Car_Ownership  CURRENT_JOB_YRS  CURRENT_HOUSE_YRS
# ...

# %%
df2.to_csv("Test Data Cleaned.csv")
